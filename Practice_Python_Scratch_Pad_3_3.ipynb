# %% [markdown]
# <a href="https://colab.research.google.com/github/michaeljulius-FC/collaborative-fidelity-site/blob/main/Practice_Python_Scratch_Pad_3_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
5==(3+2)
# Out:
# True

# %%
a=3
print(a + (33))
# Out:
# 36

# %%
a=3.5
float(a)
# Out:
# 3.5

# %%
a=3.5
int(a)
# Out:
# 3

# %%
a='5a'
int(a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3349817754.py in <cell line: 0>()
#       1 a='5a'
# ----> 2 int(a)
#
# ValueError: invalid literal for int() with base 10: '5a'

# %%
v = 10
w = 25
x = 70
y = 2
z = (v + w) * (x / y)

# %%
repeated_list=[2]*4
print(repeated_list)
# Out:
# [2, 2, 2, 2]

# %%
number=[1,12,24,36,11,20,50]
for i in number
    sq=i * i
    print(sq)
# Out:
#   File "/tmp/ipython-input-2687861806.py", line 2
#     for i in number
#                    ^
# SyntaxError: expected ':'

# %%
a=2020
if a % 2==0:
  print("Number is Even")
else:
  print("Number is Odd")
# Out:
# Number is Even

# %%
length=5
breadth=10
#find the ares and perimeter of the rectangle
Area=length*breadth
Perimeter=2*(length+breadth)
#check whether the area of the rectangle is greater than the perimeter of the rectangle
if Area>Perimeter:
  print("Area of rectangle is greater than the Perimeter of the rectangle")
else:
  print("Perimeter of the rectangle is greater than the Area of the rectangle")
# Out:
# Area of rectangle is greater than the Perimeter of the rectangle

# %%
a="I am a Data Scientist"
if "Data" in a:
  print("It is present")
else:
  print(False)
# Out:
# It is present

# %%
first=25
second=34
third=45
if first>=second and first>= third:
  print(First)
elif second>=first and second>=third:
  print(second)
elif third >=first and third>= second
  print(third)
else:
  print("All of the values are equal")
# Out:
#   File "/tmp/ipython-input-3723913592.py", line 8
#     elif third >=first and third>= second
#                                          ^
# SyntaxError: expected ':'
